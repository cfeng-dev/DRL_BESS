# %%
# %run ../src/training/train_sac.py --timesteps 1000
# Out:
# [INFO] Project root: C:\Users\ASUS\JupyterProjects\DRL_BESS
# [INFO] Data CSV    : C:\Users\ASUS\JupyterProjects\DRL_BESS\data\raw\dayahead_2024_11.csv
# [INFO] Model dir   : C:\Users\ASUS\JupyterProjects\DRL_BESS\models\sac_baseline
# [INFO] Existing model found at C:\Users\ASUS\JupyterProjects\DRL_BESS\models\sac_baseline\sac_bess_model.zip and signature matches.
# [INFO] Loading model and continuing training...
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [INFO] Loaded replay buffer from C:\Users\ASUS\JupyterProjects\DRL_BESS\models\sac_baseline\sac_bess_replay.pkl.
# [INFO] Starting learn() for 1000 timesteps (reset_num_timesteps=False)...
# [INFO] Saved model to C:\Users\ASUS\JupyterProjects\DRL_BESS\models\sac_baseline\sac_bess_model.zip
# [INFO] Saved replay buffer to C:\Users\ASUS\JupyterProjects\DRL_BESS\models\sac_baseline\sac_bess_replay.pkl
# ...
